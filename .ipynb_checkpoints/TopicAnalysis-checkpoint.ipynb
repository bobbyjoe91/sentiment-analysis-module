# %%
import numpy as np
import pandas as pd
import sqlite3

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import NMF

# %%
connection = sqlite3.connect("./bobby.cool00763_final.db")
cursor = connection.cursor()

# %%
get_data_latih = '''
    SELECT l.scraping_id, t.cleantweet, l.last_get FROM 
    Tweet t INNER JOIN Lastscraping l
    ON t.scraping_id = l.scraping_id 
'''

data_latih = pd.read_sql(con=connection, sql=get_data_latih, parse_dates=True)
data_latih['last_get'] = pd.to_datetime(data_latih['last_get'], format='%Y-%m-%d %H:%M:%S')
data_latih
# Out:
#       scraping_id                                         cleantweet  \
# 0               2  arrest bill gate conspirator pt3 covid19 virus...
# 1               2  new york covid spike school close indefinitely...
# 2               2  next pandemic force mandatoryvaccination vacci...
# 3               2  new york covid spike school close indefinitely...
# 4               2  new york covid spike school close indefinitely...
# ...           ...                                                ...
# 3745           77  covid 19 vaccine work canadian play part alber...
# 3746           77  pm modi visit 3 vaccine centre ahmedabad pune ...
# 3747           77  astrazeneca mistake covid19 vaccine trial coul...
# 3748           77  successful report covid 19 vaccine every day g...
# 3749           77  covidー19 serious disease take easy please plea...
#
#                 last_get
# 0    2020-11-19 09:43:16
# 1    2020-11-19 09:43:16
# 2    2020-11-19 09:43:16
# 3    2020-11-19 09:43:16
# 4    2020-11-19 09:43:16
# ...                  ...
# 3745 2020-11-27 20:53:15
# 3746 2020-11-27 20:53:15
# 3747 2020-11-27 20:53:15
# 3748 2020-11-27 20:53:15
# 3749 2020-11-27 20:53:15
#
# [3750 rows x 3 columns]

# %% [markdown]
# ## TF-iDF

# %%
clean_tweet = data_latih['cleantweet'].copy().values.flatten()

vectorizer = TfidfVectorizer(max_features=50)
tf_idf = vectorizer.fit_transform(clean_tweet)

# %%
vectorizer.get_feature_names()
# Out:
# ['19',
#  'astrazeneca',
#  'benefit',
#  'control',
#  'coronavaccine',
#  'coronavirus',
#  'country',
#  'covid',
#  'covid19',
#  'covid_19',
#  'day',
#  'drive',
#  'first',
#  'get',
#  'giant',
#  'government',
#  'health',
#  'india',
#  'join',
#  'let',
#  'make',
#  'moderna',
#  'need',
#  'new',
#  'news',
#  'one',
#  'oxford',
#  'pandemic',
#  'pass',
#  'patent',
#  'people',
#  'pfizer',
#  'pharma',
#  'plan',
#  'profit',
#  'restrict',
#  'rich',
#  'say',
#  'supply',
#  'sure',
#  'suspend',
#  'take',
#  'trial',
#  'use',
#  'vaccine',
#  'virus',
#  'vote',
#  'whole',
#  'world',
#  'would']

# %% [markdown]
# ## NMF Topic Modelling

# %%
nmf_decompose = NMF(n_components=3, init='nndsvd')
W = nmf_decompose.fit_transform(tf_idf)
H = nmf_decompose.components_
print(W.shape, H.shape)
# Out:
# (3750, 3) (3, 50)

# %%
topics = []
for index, topic in enumerate(H):
    feature_names = vectorizer.get_feature_names()
    topics.append(' '.join([feature_names[i] for i in topic.argsort()[-5:]]))

topics
# Out:
# ['people need take get vaccine',
#  'coronavaccine coronavirus 19 covid covid19',
#  'country world government make patent']

# %%
tweet_topics = []

for tweet in clean_tweet:
    tweet_to_vector = vectorizer.transform([tweet])
    prob_score = nmf_decompose.transform(tweet_to_vector)

    tweet_topics.append(topics[np.argmax(prob_score)])

data_latih['topic'] = tweet_topics
data_latih
# Out:
#       scraping_id                                         cleantweet  \
# 0               2  arrest bill gate conspirator pt3 covid19 virus...
# 1               2  new york covid spike school close indefinitely...
# 2               2  next pandemic force mandatoryvaccination vacci...
# 3               2  new york covid spike school close indefinitely...
# 4               2  new york covid spike school close indefinitely...
# ...           ...                                                ...
# 3745           77  covid 19 vaccine work canadian play part alber...
# 3746           77  pm modi visit 3 vaccine centre ahmedabad pune ...
# 3747           77  astrazeneca mistake covid19 vaccine trial coul...
# 3748           77  successful report covid 19 vaccine every day g...
# 3749           77  covidー19 serious disease take easy please plea...
#
#                 last_get                                       topic
# 0    2020-11-19 09:43:16  coronavaccine coronavirus 19 covid covid19
# 1    2020-11-19 09:43:16  coronavaccine coronavirus 19 covid covid19
# 2    2020-11-19 09:43:16                people need take get vaccine
# 3    2020-11-19 09:43:16  coronavaccine coronavirus 19 covid covid19
# 4    2020-11-19 09:43:16  coronavaccine coronavirus 19 covid covid19
# ...                  ...                                         ...
# 3745 2020-11-27 20:53:15  coronavaccine coronavirus 19 covid covid19
# 3746 2020-11-27 20:53:15                people need take get vaccine
# 3747 2020-11-27 20:53:15  coronavaccine coronavirus 19 covid covid19
# 3748 2020-11-27 20:53:15  coronavaccine coronavirus 19 covid covid19
# 3749 2020-11-27 20:53:15  coronavaccine coronavirus 19 covid covid19
#
# [3750 rows x 4 columns]

# %% [markdown]
# ## Analisis Tren (Jumat, 27 November 2020, 12:00-20:59)

# %%
data_27nov = data_latih[data_latih['scraping_id'] >= 43]
data_27nov[:]['last_get'] = pd.to_datetime(data_27nov['last_get'])
data_27nov[:]['last_get'] = data_27nov['last_get'].dt.strftime('%H:%M')
data_27nov.reset_index(drop=True, inplace=True)

# %%
data_27nov
# Out:
#      scraping_id                                         cleantweet  \
# 0             43  add borisjohnson dictate everyone must take co...
# 1             43  vaccine distribution start next week week fron...
# 2             43  global trial astrazeneca vaccine likely ceo as...
# 3             43  scrutiny hidden trial practice could see jab d...
# 4             43  dont want yet covid vaccine trial also kill pa...
# ..           ...                                                ...
# 738           77  covid 19 vaccine work canadian play part alber...
# 739           77  pm modi visit 3 vaccine centre ahmedabad pune ...
# 740           77  astrazeneca mistake covid19 vaccine trial coul...
# 741           77  successful report covid 19 vaccine every day g...
# 742           77  covidー19 serious disease take easy please plea...
#
#                last_get                                       topic
# 0   2020-11-27 12:11:55  coronavaccine coronavirus 19 covid covid19
# 1   2020-11-27 12:11:55                people need take get vaccine
# 2   2020-11-27 12:11:55  coronavaccine coronavirus 19 covid covid19
# 3   2020-11-27 12:11:55  coronavaccine coronavirus 19 covid covid19
# 4   2020-11-27 12:11:55        country world government make patent
# ..                  ...                                         ...
# 738 2020-11-27 20:53:15  coronavaccine coronavirus 19 covid covid19
# 739 2020-11-27 20:53:15                people need take get vaccine
# 740 2020-11-27 20:53:15  coronavaccine coronavirus 19 covid covid19
# 741 2020-11-27 20:53:15  coronavaccine coronavirus 19 covid covid19
# 742 2020-11-27 20:53:15  coronavaccine coronavirus 19 covid covid19
#
# [743 rows x 4 columns]

# %%
data_27nov.groupby(['topic'])['topic'].count()
# Out:
# topic
# coronavaccine coronavirus 19 covid covid19    360
# country world government make patent           56
# people need take get vaccine                  327
# Name: topic, dtype: int64

# %%
trend_per_topic = data_27nov.groupby(['topic']).resample('H', on='last_get')['topic'].count()

i = 0
trend_data = []
for index in list(trend_per_topic.index):
    hour_range = f'{index[1].hour}:00 - {index[1].hour}:59'
    trend_data.append([index[0], hour_range, trend_per_topic[i]])
    i += 1

trend_df = pd.DataFrame(data=trend_data, columns=['Topic', 'Time', 'n_topic'])
# trend_df['Time'] = trend_df['Time'].dt.strftime('%H:%M')
trend_df
# Out:
#                                          Topic           Time  n_topic
# 0   coronavaccine coronavirus 19 covid covid19  12:00 - 12:59       37
# 1   coronavaccine coronavirus 19 covid covid19  13:00 - 13:59       23
# 2   coronavaccine coronavirus 19 covid covid19  14:00 - 14:59       30
# 3   coronavaccine coronavirus 19 covid covid19  15:00 - 15:59       29
# 4   coronavaccine coronavirus 19 covid covid19  16:00 - 16:59       37
# 5   coronavaccine coronavirus 19 covid covid19  17:00 - 17:59       38
# 6   coronavaccine coronavirus 19 covid covid19  18:00 - 18:59       53
# 7   coronavaccine coronavirus 19 covid covid19  19:00 - 19:59       59
# 8   coronavaccine coronavirus 19 covid covid19  20:00 - 20:59       54
# 9         country world government make patent  12:00 - 12:59        9
# 10        country world government make patent  13:00 - 13:59        4
# 11        country world government make patent  14:00 - 14:59        4
# 12        country world government make patent  15:00 - 15:59        5
# 13        country world government make patent  16:00 - 16:59        5
# 14        country world government make patent  17:00 - 17:59        4
# 15        country world government make patent  18:00 - 18:59        6
# 16        country world government make patent  19:00 - 19:59       10
# 17        country world government make patent  20:00 - 20:59        9
# 18                people need take get vaccine  12:00 - 12:59       29
# 19                people need take get vaccine  13:00 - 13:59       23
# 20                people need take get vaccine  14:00 - 14:59       23
# 21                people need take get vaccine  15:00 - 15:59       32
# 22                people need take get vaccine  16:00 - 16:59       38
# 23                people need take get vaccine  17:00 - 17:59       39
# 24                people need take get vaccine  18:00 - 18:59       51
# 25                people need take get vaccine  19:00 - 19:59       36
# 26                people need take get vaccine  20:00 - 20:59       56

# %%
import seaborn as sns
# %matplotlib inline
sns.set_theme(style="whitegrid")
sns.set(rc={'figure.figsize':(20, 9)})

sns.lineplot(data=trend_df, x='Time', y='n_topic', hue='Topic', linewidth=3, markers=True, style='Topic')
# Out:
# <AxesSubplot:xlabel='Time', ylabel='n_topic'>
